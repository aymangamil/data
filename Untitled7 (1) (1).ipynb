# %%
import pandas as pd
import numpy as np
file_name='Employee Sample Data.xlsx'
data= pd.read_excel(file_name)
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
data.shape
# Out:
# (1000, 14)

# %% [markdown]
# there is 1000 employee with 14 properities

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   Job Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Business Unit  1000 non-null   object
#  5   Gender         1000 non-null   object
#  6   Ethnicity      1000 non-null   object
#  7   Age            1000 non-null   int64
#  8   Hire Date      1000 non-null   datetime64[ns]
#  9   Annual Salary  1000 non-null   int64
#  10  Bonus %        1000 non-null   float64
#  11  Country        1000 non-null   object
#  12  City           1000 non-null   object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 109.5+ KB

# %% [markdown]
# there is non null value in all columns except the colum of "ExitData"

# %%
data=data[data["Exit Date"].isnull()]
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# 5    E00644     Joshua Gupta    Account Representative       Sales
# ..      ...              ...                       ...         ...
# 994  E01148   Scarlett Kumar           Systems Analyst          IT
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#            Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 1          Manufacturing    Male      Asian   59 1997-11-29          99975
# ...

# %%
data.describe(include='all')
# Out:
# C:\Users\Ayman\AppData\Local\Temp\ipykernel_34364\1336221646.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include='all')
# C:\Users\Ayman\AppData\Local\Temp\ipykernel_34364\1336221646.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include='all')
#           EEID Full Name Job Title Department  Business Unit  Gender  \
# count      915       915       915        915            915     915
# unique     844       907        33          7              4       2
# top     E04972  Anna Han  Director         IT  Manufacturing  Female
# ...

# %% [markdown]
# in the column'EEid'
# there is 844 value unique
# the top value mentioned is E04927 by 3 times
#
# in the column'Fullname'
# there is 915 name
# there is 8 name  repetead
# the top name repetead 'Anna Han' by 2 times
#
# in the column 'job title'
# there is 33 job
# the top job joined is 'director'
# 109 employee works director
#
# in the column 'job department'
# there is 7 department
# the top departmnet is 'IT'
# "IT" works at him 225 employee
#
# in the column 'Business unit'
# there is 4 business unit
# 'manufacturing' by 248 employee is the top Business unit
#
# in the column 'Gender'
# there are 2 Gender
# 479 is female 436 is male
#
#
# in the column 'Ethnicity'
# there is 4 Ethnicity
# the top of them is Asian
# Asian Ethnicity by 366 employee
#
#
# in the column 'Age'
# the min of Age is 25
# the averge of Age is 44 year
# the max of Age is 65
#
#
# in the column 'Hire Date'
# 2011-10-20 00:00:00	 00:00:00	is the data that there are 3 employee joined the company
# 1992-01-09 00:00:00	is the first Hire date and 2021-12-26 00:00:00	is the last Hire date
#
# in the column 'annual salary'
# the min of salary is 40063
# the averge of salary is 113217.365000
# the max of salary is 258498
# there is outliers in data
#
# in the column 'Bonus'
# the min of Bounus is 0
# the averge of bounus is 0.088660
# the max of Bounus 0.400000
#
#
# in the column 'country'
# there are 3 country
# the most country with employee is united states
# there are 590 employee in united states
#
# in the column 'city'
# there are 13 city
# the most city mentioned is Seattle
# there are 110 employee in seattle
#
# in the column 'exit date'
# there is 83 different exit day
# the most exit date is 2020-07-17 00:00:00
# the first employees exit company in 1994-12-18 00:00:00
# the last employees exit company in 2022-08-17 00:00:00

# %% [markdown]
# there is 915 people  dont leave company
# there is 85 people leave the company
# 53 from people who leave is from united state

# %%
data['Full Name'].value_counts()
# Out:
# Anna Han           2
# Rylee Yu           2
# Ezra Simmons       2
# Miles Mehta        2
# Caroline Nelson    2
#                   ..
# Caroline Owens     1
# Kennedy Do         1
# Jade Acosta        1
# Mila Vasquez       1
# Sofia Cheng        1
# Name: Full Name, Length: 907, dtype: int64

# %% [markdown]
# Anna Han  is repetead         2
# Rylee Yu  is repeated         2
# Ezra Simmons   is repeated    2
# Miles Mehta    is repeated    2
# Caroline Nelson is repeated   2

# %%
data["Job Title"].value_counts()
# Out:
# Director                          109
# Vice President                    101
# Sr. Manger                        100
# Manager                            93
# Sr. Analyst                        62
# Analyst II                         48
# Analyst                            47
# Field Engineer                     20
# Computer Systems Manager           19
# Account Representative             18
# Development Engineer               18
# Quality Engineer                   18
# Network Architect                  18
# Enterprise Architect               18
# Engineering Manager                17
# Technical Architect                16
# Cloud Infrastructure Architect     15
# HRIS Analyst                       14
# Controls Engineer                  14
# Business Partner                   14
# Solutions Architect                14
# Systems Analyst                    14
# Sr. Business Partner               14
# System Administrator               13
# IT Systems Architect               11
# ...

# %% [markdown]
# -the most jobs employeed
# name                           number of employee
# Director                          109
# Vice President                    101
# Sr. Manger                        100
# Manager                            93
# Sr. Analyst                        62

# %%
data["Department"].value_counts()
# Out:
# IT                 225
# Engineering        141
# Sales              130
# Human Resources    114
# Finance            111
# Marketing          105
# Accounting          89
# Name: Department, dtype: int64

# %% [markdown]
# department       number of employee
# IT                 225
# Engineering        141
# Sales              130
# Human Resources    114
# Finance            111
# Marketing          105
# Accounting          89

# %%
data["Business Unit"].value_counts()
# Out:
# Manufacturing             248
# Speciality Products       247
# Corporate                 218
# Research & Development    202
# Name: Business Unit, dtype: int64

# %% [markdown]
# Business Unit             number of employee
# Manufacturing             248
# Speciality Products       247
# Corporate                 218
# Research & Development    202

# %%
data["Ethnicity"].value_counts()
# Out:
# Asian        366
# Caucasian    252
# Latino       233
# Black         64
# Name: Ethnicity, dtype: int64

# %%
Ethnicity    number of employee
Asian        366
Caucasian    252
Latino       233
Black         64

# %%
data['Age'].value_counts()
# Out:
# 45    66
# 55    47
# 36    29
# 46    28
# 52    28
# 28    27
# 48    27
# 33    25
# 30    25
# 37    25
# 29    24
# 41    23
# 64    23
# 31    23
# 27    23
# 42    23
# 40    22
# 51    22
# 54    22
# 60    21
# 34    21
# 43    20
# 47    20
# 53    20
# 25    19
# 50    19
# 32    19
# 59    19
# 39    18
# 49    18
# 61    18
# 63    18
# 38    17
# 35    16
# 62    16
# 26    16
# 56    15
# 65    14
# 57    14
# 44    13
# 58    12
# Name: Age, dtype: int64

# %% [markdown]
# people with age 45 is 66 employee
# people with age 55 is 47 employee
# people with age 48 is 29 employee
# people with age 36 is 28 employee
# people with age 52 is 28 employee

# %%
data["Annual Salary"].value_counts()
# Out:
# 157057    2
# 70165     2
# 177443    2
# 146140    2
# 94652     1
#          ..
# 50069     1
# 151108    1
# 67398     1
# 68488     1
# 216195    1
# Name: Annual Salary, Length: 911, dtype: int64

# %% [markdown]
# most salaries
# salary    repeated
#
# 157057    2
# 70165     2
# 177443    2
# 146140    2
# 94652     1
#          ..
# 50069     1
# 151108    1
# 67398     1
# 68488     1
# 216195    1

# %%
data["Country"].value_counts()
# Out:
# United States    590
# China            197
# Brazil           128
# Name: Country, dtype: int64

# %% [markdown]
# country         number of employee
# United States    590
# China            197
# Brazil           128

# %%
data['City'].value_counts()
# Out:
# Seattle           110
# Phoenix           104
# Columbus          104
# Miami              99
# Austin             88
# Chicago            85
# Chongqing          58
# Beijing            49
# Sao Paulo          49
# Shanghai           48
# Rio de Janerio     42
# Chengdu            42
# Manaus             37
# Name: City, dtype: int64

# %%
city            number of employee
Seattle           110
Phoenix           104
Columbus          104
Miami              99
Austin             88
