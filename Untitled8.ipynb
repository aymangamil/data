# %%
import pandas as pd
import numpy as np
file_name='sample-xlsx-file-for-testing.xlsx'
df=pd.read_excel(file_name)
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount Band        700 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           700 non-null    int64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9    Sales               700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %%
there is no null values

# %%
df.shape
# Out:
# (700, 16)

# %% [markdown]
# there is 700 row and 16 column

# %%
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
df.describe(include='all')
# Out:
# C:\Users\Ayman\AppData\Local\Temp\ipykernel_25644\2884002236.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#            Segment Country Product Discount Band   Units Sold  \
# count          700     700     700           700   700.000000
# unique           5       5       6             4          NaN
# top     Government  Canada   Paseo          High          NaN
# freq           300     140     202           245          NaN
# first          NaN     NaN     NaN           NaN          NaN
# last           NaN     NaN     NaN           NaN          NaN
# mean           NaN     NaN     NaN           NaN  1608.294286
# std            NaN     NaN     NaN           NaN   867.427859
# min            NaN     NaN     NaN           NaN   200.000000
# ...

# %% [markdown]
# in the column 'segment'
#
# there is 5 segment
# the most segment in country is 'Government'
# the number of 'Government' is 300 in 700 data
#
# in the column 'country'
#
# there is 5 country
# the top country is 'canda' by 140 segment
#
# in the column 'product'
#
# there is 6 product
# the most product is 'paseo' by 202 segment
#
# in the column 'Discount Band'
#
# Discount Band is offered by 4 degree
# the most degree is 'High'by 245 segment and 455 "low"
#
# in the column 'Units Sold'
#
# the min of unit sold is 200
# the averge of unit sold is 1608
# the max of unit sold is 4492
#
# in the column 'Manufacturing Price'
#
# the min 'manufacturing price'       is 3
# the averge of 'manufacturing price' is 96
# the max of 'manufacturing price'    is 260
#
#
# in the column 'Sale Price'
#
# the min ' sale price'      is 7
# the averge of 'Sale Price'  is 118
# the max of 'Sale Price'    is 350
#
# in the column 'gross sales'
#
# the min 'gross sales'        is 1.799000e+03
# the averge of 'gross sales'  is 1.827594e+05
# the max of 'gross sales'     is	1.207500e+06
#
# in the column 'discounts'
#
# the min 'Discounts'        is 0
# the averge of 'Discounts'  is 13150
# the max of 'Discounts'     is 149677.5
#
# in the column 'sales'
#
# the min 'Discounts'        is 1.655080e+03
# the averge of 'Discounts'  is 1.696091e+05
# the max of 'Discounts'     is 1.159200e+06
#
#
#
# in the column 'COGS'
#
# the min of 'COGS'     is 918
# the averge of 'COGS'  is 145475
# the max of 'COGS'    is 950625
#
#
# in the column 'profit'
#
# the min of 'profit'     is 24133
# the averge of 'profit'  is -40617
# the max of 'profit'     is 2622200
#
#
# in the column 'Date'
#
# the most date mentioned 2014-06-01 by 70 times
# the first date mentioned 2013-09-01
# the last date mentioned  2014-12-01

# %%
x=df.pivot_table(index='Month Name'
               ,values=['Profit']
               ,aggfunc=np.max
              )

# %%
x
# Out:
#               Profit
# Month Name
# April       108147.0
# August      154385.0
# December    236716.0
# February    247500.0
# January     141394.5
# July        262200.0
# June        117124.0
# March       115345.5
# May         127215.0
# November    155250.0
# October     246178.0
# September   188378.0

# %%
x.sort_values(by=["Profit"],ascending=True)
# Out:
#               Profit
# Month Name
# April       108147.0
# March       115345.5
# June        117124.0
# May         127215.0
# January     141394.5
# August      154385.0
# November    155250.0
# September   188378.0
# December    236716.0
# October     246178.0
# February    247500.0
# July        262200.0

# %% [markdown]
# the most months that has profit is
#
#
# Month Name   Profit
#
# September	188378
# December	236716
# October	    246178
# February	247500
# July	    262200
# * july is the month that has the maximum profit

# %%
y= df.pivot_table( index="Year"
                  ,values=["Profit"]
                  ,aggfunc=np.max
)

# %%
y.sort_values(by=["Profit"],ascending=True)
# Out:
#         Profit
# Year
# 2013  246178.0
# 2014  262200.0

# %% [markdown]
# the most year has profit on it is 2014

# %%
df["Segment"].value_counts()
# Out:
# Government          300
# Midmarket           100
# Channel Partners    100
# Enterprise          100
# Small Business      100
# Name: Segment, dtype: int64

# %% [markdown]
# the number of segment
# segment             number
# Government          300
# Midmarket           100
# Channel Partners    100
# Enterprise          100
# Small Business      100

# %%
df["Country"].value_counts()
# Out:
# Canada                      140
# Germany                     140
# France                      140
# Mexico                      140
# United States of America    140
# Name: Country, dtype: int64

# %% [markdown]
# the  number of countries
# country                    number
# Canada                      140
# Germany                     140
# France                      140
# Mexico                      140
# United States of America    140

# %%
df["Product"].value_counts()
# Out:
# Paseo        202
# Velo         109
# VTT          109
# Amarilla      94
# Carretera     93
# Montana       93
# Name: Product, dtype: int64

# %%
z= df.pivot_table(index="Product"
                  ,values=['Profit']
                  ,aggfunc=np.max
)

# %%
z.sort_values(by=["Profit"],ascending=True)
# Out:
#              Profit
# Product
# Montana    142861.5
# Carretera  236716.0
# VTT        238791.0
# Velo       246178.0
# Amarilla   247500.0
# Paseo      262200.0

# %% [markdown]
# the most product sells and their profit
# product      sells  money
#
# Paseo        202   262200
# Velo         109   246178
# VTT          109   238791
# Amarilla      94   247500
# Carretera     93   236716
# Montana       93   142861.5
# 'montana' is less sells and profit

# %%
d=df.pivot_table( index='Manufacturing Price'
               , values=['Sale Price']
               , aggfunc=np.max
              )

# %%
d.sort_values(by=["Sale Price"],ascending=True)
# Out:
#                      Sale Price
# Manufacturing Price
# 3                           350
# 5                           350
# 10                          350
# 120                         350
# 250                         350
# 260                         350

# %%
t=df.pivot_table( index='Manufacturing Price'
               , values=['Sale Price']
               , aggfunc=np.min
              )

# %%
t.sort_values(by=["Sale Price"],ascending=True)
# Out:
#                      Sale Price
# Manufacturing Price
# 3                             7
# 5                             7
# 10                            7
# 120                           7
# 250                           7
# 260                           7

# %% [markdown]
# the maximum sale price that the company sells is 350$ (one piece)
# the minumum sale price that the company sells is 7$ (one piece)
